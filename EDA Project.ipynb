# %% [markdown]
# #  Name-- Challa Rohan Reddy

# %% [markdown]
# # Reg.No.-- 12016138

# %% [markdown]
# # Roll No.--- RK20MPA25

# %% [markdown]
#  # Section---  K20MP

# %% [markdown]
# # Course Code---  INT-353

# %% [markdown]
# #  Data Set--- Chocolate Bar Ratings

# %% [markdown]
# # Introduction

# %% [markdown]
# # I have choosen a data set from kaggle it is about a Chocolate Bar Ratings

# %% [markdown]
# # Importing lib

# %%
import numpy as nd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading CSV Files

# %%
data=pd.read_csv("chocolate_bars.csv")
df=pd.DataFrame(data)

# %%
df
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
# ...

# %%
df = pd.read_csv('chocolate_bars.csv')
df.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
df.shape
# Out:
# (2530, 11)

# %%
df.describe()
# Out:
#                 id  year_reviewed  cocoa_percent  num_ingredients       rating
# count  2530.000000    2530.000000    2530.000000      2443.000000  2530.000000
# mean   1429.800791    2014.374308      71.639723         3.041343     3.196344
# std     757.648556       3.968267       5.616724         0.913728     0.445321
# min       5.000000    2006.000000      42.000000         1.000000     1.000000
# 25%     802.000000    2012.000000      70.000000         2.000000     3.000000
# 50%    1454.000000    2015.000000      70.000000         3.000000     3.250000
# 75%    2079.000000    2018.000000      74.000000         4.000000     3.500000
# max    2712.000000    2021.000000     100.000000         6.000000     4.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
# ...

# %% [markdown]
# # Checking of Null Values

# %%
df.isnull().sum()
# Out:
# id                   0
# manufacturer         0
# company_location     0
# year_reviewed        0
# bean_origin          0
# bar_name             0
# cocoa_percent        0
# num_ingredients     87
# ingredients         87
# review               0
# rating               0
# dtype: int64

# %%
data["ingredients"].value_counts()
# Out:
# B,S,C           999
# B,S             718
# B,S,C,L         286
# B,S,C,V,L       184
# B,S,C,V         141
# B,S*             31
# B,S*,C,Sa        20
# B,S*,C           12
# B,S,L             8
# B,S*,C,V          7
# B                 6
# B,S,C,V,Sa        6
# B,S,V,L           5
# B,S,C,Sa          5
# B,S,C,V,L,Sa      4
# B,S,V             3
# B,S*,V,L          3
# B,S*,C,L          2
# B,S*,Sa           1
# B,C               1
# B,S,C,L,Sa        1
# Name: ingredients, dtype: int64

# %%
data.dtypes
# Out:
# id                    int64
# manufacturer         object
# company_location     object
# year_reviewed         int64
# bean_origin          object
# bar_name             object
# cocoa_percent       float64
# num_ingredients     float64
# ingredients          object
# review               object
# rating              float64
# dtype: object

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.boxplot('rating')
# Out:
# <AxesSubplot:>

# %%
df.boxplot("id")
# Out:
# <AxesSubplot:>

# %%
df.boxplot("year_reviewed")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Wrangling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 217.5+ KB

# %% [markdown]
# # Checking for Duplicate

# %%
# check duplicated values
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, manufacturer, company_location, year_reviewed, bean_origin, bar_name, cocoa_percent, num_ingredients, ingredients, review, rating]
# Index: []

# %% [markdown]
# There is no duplicate values

# %%
# drop duplicated values
df.drop_duplicates(inplace=True)

# %%
df['rating'].unique()
# Out:
# array([3.25, 3.5 , 3.75, 3.  , 2.75, 4.  , 2.5 , 1.75, 2.25, 1.5 , 2.  ,
#        1.  ])

# %%
df.bean_origin.nunique()
# Out:
# 62

# %%
# look again to dataset
df.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %% [markdown]
# # Finding Outliers

# %%
import warnings
plt.figure(figsize=(15,20))
plt.subplot(4,2,1)
sns.distplot(df['rating'])
plt.subplot(4,2,2)
sns.boxplot(df['rating'])
plt.subplot(4,2,3)
sns.distplot(df['year_reviewed'])
plt.subplot(4,2,4)
sns.boxplot(df['year_reviewed'])
plt.subplot(4,2,5)
sns.distplot(df['id'])
plt.subplot(4,2,6)
sns.boxplot(df['id'])
plt.subplot(4,2,7)
sns.distplot(df['num_ingredients'])
plt.subplot(4,2,8)
sns.boxplot(df['num_ingredients'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(12,6))
sns.boxplot(df["year_reviewed"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.violinplot(df["rating"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df["cocoa_percent"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(df.cocoa_percent)

# %%
plt.plot(df.rating)

# %%
plt.plot(df.year_reviewed)

# %% [markdown]
# # Percentage

# %%
(174/2530)*100
# Out:
# 6.877470355731226

# %%
percentage=(174/df.shape[0])*100
percentage
# Out:
# 6.877470355731226

# %%
plt.bar(['null values','total values'],[percentage,df.shape[0]])
plt.show()

# %% [markdown]
# # Piechart

# %%
df.cocoa_percent.value_counts(normalize=True)
# Out:
# 70.0     0.413439
# 75.0     0.122530
# 72.0     0.116601
# 65.0     0.035573
# 80.0     0.035178
# 68.0     0.028458
# 74.0     0.026482
# 73.0     0.026087
# 60.0     0.018182
# 71.0     0.016996
# 77.0     0.016601
# 85.0     0.015810
# 76.0     0.013834
# 67.0     0.013439
# 64.0     0.013439
# 66.0     0.011067
# 100.0    0.008300
# 78.0     0.008300
# 82.0     0.007115
# 55.0     0.006324
# 62.0     0.006324
# 63.0     0.005534
# 69.0     0.005138
# 90.0     0.003557
# 88.0     0.003162
# 58.0     0.003162
# 61.0     0.002767
# 81.0     0.002372
# 83.0     0.001976
# 84.0     0.001581
# 72.5     0.001581
# 91.0     0.001186
# 99.0     0.000791
# 89.0     0.000791
# 79.0     0.000791
# 71.5     0.000791
# 73.5     0.000791
# 56.0     0.000791
# 46.0     0.000395
# 53.0     0.000395
# 50.0     0.000395
# 57.0     0.000395
# 60.5     0.000395
# 42.0     0.000395
# 86.0     0.000395
# 87.0     0.000395
# Name: cocoa_percent, dtype: float64

# %%
df.cocoa_percent.value_counts(normalize=True).plot.pie()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1616: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %%
rating = df.rating.mode()[0]
rating
# Out:
# 3.5

# %%
df.rating.fillna(rating, inplace=True)
df.rating.value_counts(normalize=True)
# Out:
# 3.50    0.223320
# 3.00    0.206719
# 3.25    0.183399
# 2.75    0.131621
# 3.75    0.118577
# 2.50    0.065613
# 4.00    0.044269
# 2.00    0.013043
# 2.25    0.006719
# 1.50    0.003953
# 1.00    0.001581
# 1.75    0.001186
# Name: rating, dtype: float64

# %%
df.loc[df.rating<0,"rating"]
df.rating.describe()
# Out:
# count    2530.000000
# mean        3.196344
# std         0.445321
# min         1.000000
# 25%         3.000000
# 50%         3.250000
# 75%         3.500000
# max         4.000000
# Name: rating, dtype: float64

# %%
df.loc[df.cocoa_percent<0,"cocoa_percent"]
df.cocoa_percent.describe()
# Out:
# count    2530.000000
# mean       71.639723
# std         5.616724
# min        42.000000
# 25%        70.000000
# 50%        70.000000
# 75%        74.000000
# max       100.000000
# Name: cocoa_percent, dtype: float64

# %%
df.year_reviewed.value_counts(normalize=True)
# Out:
# 2015    0.112253
# 2014    0.097628
# 2018    0.090119
# 2016    0.085771
# 2012    0.076680
# 2019    0.076285
# 2013    0.072332
# 2021    0.069170
# 2011    0.064427
# 2009    0.048617
# 2010    0.043478
# 2017    0.041502
# 2008    0.036364
# 2020    0.032016
# 2007    0.028854
# 2006    0.024506
# Name: year_reviewed, dtype: float64

# %%
df.year_reviewed.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df.rating.value_counts(normalize=True)
# Out:
# 3.50    0.223320
# 3.00    0.206719
# 3.25    0.183399
# 2.75    0.131621
# 3.75    0.118577
# 2.50    0.065613
# 4.00    0.044269
# 2.00    0.013043
# 2.25    0.006719
# 1.50    0.003953
# 1.00    0.001581
# 1.75    0.001186
# Name: rating, dtype: float64

# %%
df.rating.value_counts(normalize=True).plot.pie()
plt.show()

# %%
df.cocoa_percent.value_counts(normalize=True).plot.pie()
plt.show()

# %%
df.rating.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### These are the outliers of the Ratings

# %%
x=df["rating"].max()
print("The maximum value of the rating is {}".format(x))
# Out:
# The maximum value of the rating is 4.0

# %% [markdown]
# # # finding IQR

# %%
percentile25 = df['cocoa_percent'].quantile(0.25)
print(percentile25)
percentile75 = df['cocoa_percent'].quantile(0.75)
print(percentile75)
# Out:
# 70.0
# 74.0

# %%
print("Highest allowed",df['rating'].mean() + 3*df['rating'].std())
print("Lowest allowed",df['rating'].mean() - 3*df['rating'].std())
print("Highest allowed",df['year_reviewed'].mean() + 3*df['year_reviewed'].std())
print("Lowest allowed",df['year_reviewed'].mean() - 3*df['year_reviewed'].std())
print("Highest allowed",df['id'].mean() + 3*df['id'].std())
print("Lowest allowed",df['id'].mean() - 3*df['id'].std())
print("Highest allowed",df['num_ingredients'].mean() + 3*df['num_ingredients'].std())
print("Lowest allowed",df['num_ingredients'].mean() - 3*df['num_ingredients'].std())
# Out:
# Highest allowed 4.532307786169479
# Lowest allowed 1.8603799608660947
# Highest allowed 2026.2791101127098
# Lowest allowed 2002.469506488081
# Highest allowed 3702.746459201442
# Lowest allowed -843.1448781737743
# Highest allowed 5.782527542629736
# Lowest allowed 0.3001576804566337

# %%
Q1=df['cocoa_percent'].quantile(0.25)       # df.unatile(0.25) gives the 25th percentile of a column

Q3=df['cocoa_percent'].quantile(0.75)       # df.unatile(0.25) gives the 25th percentile of a column
Q1,Q3
# Out:
# (70.0, 74.0)

# %%
IQR = Q3-Q1                      #IQR = difference between 75th percentile and 25th percentile
IQR
# Out:
# 4.0

# %%
lower_limit = Q1 - 1.5*IQR         # lower and upper limit to display the dataset without outliers
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (64.0, 80.0)

# %%
df_no=[(df['rating']>lower_limit)&(df['rating']<upper_limit)] # we display the dataset without outliers
df_no
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  2525    False
#  2526    False
#  2527    False
#  2528    False
#  2529    False
#  Name: rating, Length: 2530, dtype: bool]

# %% [markdown]
# # exploratory Data Analysis

# %%
# check correlation
sns.heatmap(df.corr(), linecolor='w');

# %% [markdown]
# we notice there's correlation between (rating, num,_ingredients) and (num_ingredients, cocoa_percent) and (id, year_reviewed)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Bean Origin of best rated chocolate bars

# %%
fig, ax = plt.subplots(figsize=[12,6])
sns.boxplot(data=df, y='rating', x='bean_origin',ax=ax)
plt.xticks(rotation = 90)
fig.tight_layout()

# %%
df_by_origin = df.groupby(by='bean_origin')['rating'].describe()
sort_by_median = df_by_origin.sort_values(by='50%', ascending=False)
sort_by_75perc = df_by_origin.sort_values(by='75%', ascending=False)

# %%
sort_by_median.reset_index().loc[:4,'bean_origin']
# Out:
# 0                 Tobago
# 1    Sao Tome & Principe
# 2               Thailand
# 3                  China
# 4                   Cuba
# Name: bean_origin, dtype: object

# %%
sort_by_75perc.reset_index().loc[:4,'bean_origin']
# Out:
# 0                 Tobago
# 1        Solomon Islands
# 2                   Cuba
# 3                Jamaica
# 4    Sao Tome & Principe
# Name: bean_origin, dtype: object

# %% [markdown]
# Answer: The best beans come from Tobago, Sao Tome & Principe and Thailand/China, or Tobago, Solomon Islands and Cuba
# respectively (depending on which measure you are lookin (median or 75% percentile)

# %% [markdown]
# ### Do cacao percentage or ingredients correlate with rating?

# %%
sns.pairplot(df)

# %%
sns.regplot(x="cocoa_percent", 
                y="rating", 
                data=df)

y = df["cocoa_percent"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# -0.14668959508034718

# %%
sns.regplot(x="id", 
                y="rating", 
                data=df)

y = df["id"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# 0.11339775178464995

# %%
sns.regplot(x="year_reviewed", 
                y="rating", 
                data=df)

y = df["year_reviewed"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# 0.11625575400149586

# %%
sns.regplot(x="num_ingredients", 
                y="rating", 
                data=df)

y = df["num_ingredients"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)
# Out:
# -0.09883439748105385

# %% [markdown]
# Answer: No correlation observed

# %% [markdown]
# # Which countries of bean origin results in the highest rating?

# %%
plt.figure(figsize = (10,25))

sns.catplot(x = 'bean_origin',
            y = 'rating',
            kind = "bar",
            height = 10,
            aspect = 2,            
            data = df.head(2530)).set(title = "Bean Origin vs Ratings");

plt.xticks(rotation = 90)
plt.xlabel("Bean Origin",fontsize=14)
plt.ylabel("Ratings",fontsize=14)

plt.show()

# %% [markdown]
# Answers:
#
# By absolute values: Tobago, Australia, Malaysia
#
# By average values: Tobago, Sao Tome & Principle, China

# %% [markdown]
# # Does cocoa percentage or ingredients affect the rating?

# %%
y = df["cocoa_percent"]
x = df["rating"]
correlation = y.corr(x)
print(correlation)

plt.figure(figsize = (25,10))
sns.regplot(x="cocoa_percent", 
                y="rating", 
                data=df)
plt.title("Bean Origin vs Rating",fontsize=14)
plt.xticks(rotation = 0)
plt.xlabel("Cacao persentage",fontsize=14)
plt.ylabel("Ratings",fontsize=14)
plt.show()
# Out:
# -0.14668959508034718

# %% [markdown]
# Answer:
#
# No (corr=-0.14)

# %% [markdown]
# # With these high rates, what are the most memorable characteristics?

# %%
plt.figure(figsize = (25,10))

df.groupby('company_location').mean()['rating'].plot(kind='bar',color='tan')

plt.xticks(rotation=90)
plt.xlabel("Company location",fontsize=14)
plt.ylabel("Rating'",fontsize=14)
plt.title("Company location versus rating",fontsize=14)

plt.show()

# %% [markdown]
# Answer:
#
# the highest rated chocolate bars produced by companies located in Chile

# %% [markdown]
# ## Cocoa Percentage patterns over the year

# %%
dcoco = df.groupby('year_reviewed').aggregate({'cocoa_percent':'mean'})
dcoco = dcoco.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='cocoa_percent', data=dcoco)
ax.set(xticks=dcoco.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Cocoa Percentage")
plt.title("Cocoa Percentage patterns over the years \n")
plt.show()

# %% [markdown]
# Rating of chocolate bars over the years

# %% [markdown]
# # Average Ratings over the year

# %%
drate = df.groupby('year_reviewed').aggregate({'rating':'mean'})
drate = drate.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='rating', data=drate)
ax.set(xticks=drate.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Rating")
plt.title("Average Rating over the years \n")
plt.show()

# %% [markdown]
# Chocolate companies

# %% [markdown]
# # Top 10 companies in terms of chocolate bars

# %%
# Top 10 companies in terms of chocolate bars 
d = df['company_location'].value_counts().sort_values(ascending=False).head(10)
d = pd.DataFrame(d)
d = d.reset_index() # dataframe with top 10 companies

# Plotting
sns.set()
plt.figure(figsize=(10,4))
sns.barplot(x='index', y='company_location', data=d)
plt.xlabel("\nChocolate Company")
plt.ylabel("Number of Bars")
plt.title("Top 5 Companies in terms of Chocolate Bars\n")
plt.show()

# %% [markdown]
# Some produces max number of chocolate bars.

# %% [markdown]
# ## Top 10 companies in terms of average ratings

# %%
# Top 10 companies in terms of average ratings
d2 = df.groupby('company_location').aggregate({'rating':'mean'})
d2 = d2.sort_values('rating', ascending=False).head(10)
d2 = d2.reset_index()

# Plotting
sns.set()
plt.figure(figsize=(20, 6))
sns.barplot(x='company_location', y='rating', data=d2)
plt.xlabel("\nChocolate Company")
plt.ylabel("Average Rating")
plt.title("Top 10 Companies in terms of Average Ratings \n")
plt.show()

# %% [markdown]
# Top 10 companies in terms of average ratings

# %%
# Average rating over the years wrt companies
top10_dict = {}
# Top 10 companies in terms of chocolate bars in this dataset
d = df['company_location'].value_counts().sort_values(ascending=False).head(10)
d = pd.DataFrame(d)
d = d.reset_index() # dataframe with top 10 companies
for element in list(d['index']):
    temp = df[df['company_location']==element]
    top10_dict[element]=temp

top10_list = list(top10_dict.keys())

# Rating over the years
d7 = df.groupby(['year_reviewed', 'company_location']).aggregate({'rating':'mean'})
d7 = d7.reset_index()
d7 = d7[d7['company_location'].isin(top10_list)]


# Plotting
sns.set()
plt.figure(figsize=(15, 4))
ax = sns.lineplot(x='year_reviewed', y='rating', hue="company_location", data=d7, palette="husl")
ax.set(xticks=d7.year_reviewed.values)
plt.xlabel("\nDate of Review")
plt.ylabel("Average Rating")
plt.title("Average Rating over the years (Top 10 Producer Companies)\n")
plt.show()

# %% [markdown]
# Analysing the largest chocolate bar producer - Some

# %% [markdown]
# Categorizing chocolate bars based on their rating

# %%
unsatisfactory = df[df['rating'] < 3.0]
satisfactory = df[(df['rating'] >= 3.0) & (df.rating < 4)]
pre_elite = df[df['rating'] >= 4.0]
label_names=['Unsatisfactory','Above Satisfactory','Premium']
sizes = [unsatisfactory.shape[0],satisfactory.shape[0],pre_elite.shape[0]]

# Making the donut plot
explode = (0.05,0.05,0.05)
my_circle=plt.Circle((0,0),0.7,color='white')
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=label_names,explode=explode,autopct='%1.1f%%',pctdistance=0.85,startangle=90,shadow=True)
fig=plt.gcf()
fig.gca().add_artist(my_circle)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Counts of each rating of chocolate bars

# %%
# The counts of each rating
r=list(df['rating'].value_counts())
rating=df['rating'].value_counts().index.tolist()
rat=dict(zip(rating,r))
for key,val in rat.items():
    print ('Rating:',key,'Reviews:',val)
plt.figure(figsize=(10,5))
sns.countplot(x='rating',data=df)
plt.xlabel('Rating of chocolate bar',size=12,color='blue')
plt.ylabel('Number of Chocolate bars',size=12,color='blue')
plt.show()
# Out:
# Rating: 3.5 Reviews: 565
# Rating: 3.0 Reviews: 523
# Rating: 3.25 Reviews: 464
# Rating: 2.75 Reviews: 333
# Rating: 3.75 Reviews: 300
# Rating: 2.5 Reviews: 166
# Rating: 4.0 Reviews: 112
# Rating: 2.0 Reviews: 33
# Rating: 2.25 Reviews: 17
# Rating: 1.5 Reviews: 10
# Rating: 1.0 Reviews: 4
# Rating: 1.75 Reviews: 3

# %% [markdown]
# Distribution of chocolate bars according to their cocoa percentage

# %%
#Top 10 cocoa % is taken
plt.figure(figsize=(10,5))
df['cocoa_percent'].value_counts().head(10).sort_index().plot.bar()
plt.xlabel('Percentage of Cocoa',size=12)
plt.ylabel('Number of Chocolate bars',size=12)
plt.show()

# %% [markdown]
# Where the best cocoa beans are grown (based on rating)

# %%
countries=df['bean_origin'].value_counts().index.tolist()[:5]
satisfactory={} 
for j in countries:
    c=0
    b=df[df['bean_origin']==j]
    br=b[b['rating']>=3] 
    for i in br['rating']:
        c+=1
        satisfactory[j]=c    

# Code to visualize the countries that give best cocoa beans
li=satisfactory.keys()
plt.figure(figsize=(10,5))
plt.bar(range(len(satisfactory)), satisfactory.values(), align='center',color=['#a22a2a','#511515','#e59a9a','#d04949','#a22a2a'])
plt.xticks(range(len(satisfactory)), list(li))
plt.xlabel('\nCountry')
plt.ylabel('Number of chocolate bars')
plt.title("Top 5 Broad origins of the Chocolate Beans with a Rating above 3.0\n")
plt.show()

print(satisfactory)
# Out:
# {'Venezuela': 199, 'Peru': 179, 'Dominican Republic': 182, 'Ecuador': 162, 'Madagascar': 147}

# %% [markdown]
# Analysing the top chocolate bar producing countries (in terms of quantity)

# %%
print ('Top Chocolate Producing Countries in the World\n')
country=list(df['company_location'].value_counts().head(10).index)
choco_bars=list(df['company_location'].value_counts().head(10))
prod_ctry=dict(zip(country,choco_bars))
print(df['company_location'].value_counts().head())

plt.figure(figsize=(10,5))
plt.hlines(y=country,xmin=0,xmax=choco_bars,color='skyblue')
plt.plot(choco_bars,country,"o")
plt.xlabel('Country')
plt.ylabel('Number of chocolate bars')
plt.title("Top Chocolate Producing Countries in the World")
plt.show()
# Out:
# Top Chocolate Producing Countries in the World
#
# U.S.A.    1136
# Canada     177
# France     176
# U.K.       133
# Italy       78
# Name: company_location, dtype: int64

# %% [markdown]
# Visualizing countries that produce best chocolates

# %%
countries=country
best_choc={}
for j in countries:
    c=0
    b=df[df['company_location']==j]
    br=b[b['rating']>=4] 
    for i in br['rating']:
        c+=1
        best_choc[j]=c    


li=best_choc.keys()
# The lollipop plot
plt.hlines(y=li,xmin=0,xmax=best_choc.values(),color='darkgreen')
plt.plot(best_choc.values(),li,"o")
plt.xlabel('Country')
plt.ylabel('Number of chocolate bars')
plt.title("Top Chocolate Producing Countries in the World (Ratings above 4.0)")
plt.show()
print(best_choc)
# Out:
# {'U.S.A.': 42, 'Canada': 15, 'France': 18, 'U.K.': 4, 'Italy': 4, 'Belgium': 5, 'Ecuador': 3, 'Australia': 4, 'Switzerland': 6, 'Germany': 1}

# %%
fig, ax = plt.subplots(figsize=[12,6])
sns.boxplot(data=df, y='rating', x='bean_origin',ax=ax)
plt.xticks(rotation = 90)
fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
sns.barplot(x='company_location', y='rating', data=df, ax=ax[0])
sns.barplot(x='company_location', y='num_ingredients', data=df, ax=ax[1])
sns.barplot(x='company_location', y='year_reviewed', data=df, ax=ax[2])
plt.show()

# %%
plt.figure(figsize = (10,25))

sns.catplot(x = 'bean_origin',
            y = 'rating',
            kind = "bar",
            height = 10,
            aspect = 2,            
            data = df.head(2530)).set(title = "Bean Origin vs Ratings");

plt.xticks(rotation = 90)
plt.xlabel("Bean Origin",fontsize=14)
plt.ylabel("Ratings",fontsize=14)

plt.show()

# %%
plt.figure(figsize = (10,25))

sns.catplot(x = 'bean_origin',
            y = 'rating',
            kind = "bar",
            height = 10,
            aspect = 2,            
            data = df.head(2530)).set(title = "Bean Origin vs Ratings");

plt.xticks(rotation = 90)
plt.xlabel("Bean Origin",fontsize=14)
plt.ylabel("Ratings",fontsize=14)

plt.show()

# %%
sns.pairplot(df)

# %%
states= df.groupby(['year_reviewed'])[['cocoa_percent', 'id']].sum()
states.sort_values("id", ascending=False).plot(kind = 'bar', figsize = (20,8))
plt.show()

# %%
states= df.groupby(['year_reviewed']).sum().sort_values('cocoa_percent', ascending=False)
states.reset_index(inplace=True)

fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='year_reviewed', y='cocoa_percent', data=states)
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# *cocoa_percent was increased in the year of 2015 and 2015
# *More increased in 2015

# %%
fig, ax = plt.subplots(figsize=(15, 5))
states = states.sort_values('year_reviewed', ascending=False)
sns.barplot(x='id', y='year_reviewed', data=states);
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='year_reviewed', y='num_ingredients', data=states);
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Num_ingredients are increased in 2015

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='num_ingredients', y='rating', data=df);
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0])
plt.show()

# %%
df['company_location'].value_counts(normalize=True).plot.barh(figsize=[30,40])
plt.show()       # values counts gives the value counts of values of the choosen coloums

# %%
df['rating'].value_counts(normalize=True).plot.barh(figsize=[30,40])
plt.show()              # values counts gives the value counts of values of the choosen coloums

# %%
df['id'].value_counts().head(30).plot.barh(figsize=[10,10])
plt.show()

# %%
df['num_ingredients'].value_counts().head(30).plot.barh(figsize=[10,7])
plt.show()

# %%
df['rating'].value_counts().head(30).plot.barh(figsize=[10,7])
plt.show()

# %%
df[df['rating']=='Personal care'].groupby(['cocoa_percent','num_ingredients'])['id'].count().reset_index()
# Out:
# Empty DataFrame
# Columns: [cocoa_percent, num_ingredients, id]
# Index: []

# %% [markdown]
# # Multivarient Analysis

# %% [markdown]
#    # Pair Plot

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="cocoa_percent")
plt.show()

# %%
# Shows the pairplot with resppect to cocoa_percent
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="id")
plt.show()

# %%
df= df.dropna()
sns.pairplot(df)

# %% [markdown]
# # Correlations

# %%
# Shows the heatmap graph
corr_df = df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr_df,square=True)
plt.show()

# %%
sns.scatterplot(df['cocoa_percent'], df['rating'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cocoa_percent', ylabel='rating'>

# %%
sns.scatterplot(df['year_reviewed'], df['num_ingredients'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year_reviewed', ylabel='num_ingredients'>

# %%
sns.scatterplot(df['id'], df['company_location'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='id', ylabel='company_location'>

# %%
sale_columns = ('id', 'rating', 'cocoa_percent', 'num_ingredients')
total_sales_platform = df.groupby('year_reviewed').sum().loc[:,sale_columns].dropna(axis=1, thresh=4)
mean_sales_platform=df.groupby('year_reviewed').mean().loc[:,sale_columns]

fig, axes_platform_heatmap = plt.subplots(2, 1, figsize=(24,10))

axes_platform_heatmap[0].set_title("Total Sales in Each Region by Genre")
sns.heatmap(data=total_sales_platform.transpose(), ax=axes_platform_heatmap[0], annot=True, fmt=".3g")

axes_platform_heatmap[1].set_title("Mean Sales in Each Region by Genre")
sns.heatmap(data=mean_sales_platform.transpose(), ax=axes_platform_heatmap[1], annot=True, fmt=".3f")
# Out:
# <AxesSubplot:title={'center':'Mean Sales in Each Region by Genre'}, xlabel='year_reviewed'>

# %%
total_sales_genre=df.groupby('year_reviewed').sum().loc[:,sale_columns]
mean_sales_genre=df.groupby('year_reviewed').mean().loc[:,sale_columns]


fig, axes_genre_heatmap = plt.subplots(1, 2, figsize=(14,8))

axes_genre_heatmap[0].set_title("Total Sales in Each Region by Genre")
sns.heatmap(data=total_sales_genre, ax=axes_genre_heatmap[0], annot=True, fmt=".3g")

axes_genre_heatmap[1].set_title("Mean Sales in Each Region by Genre")
sns.heatmap(data=mean_sales_genre, ax=axes_genre_heatmap[1], annot=True, fmt=".3g")
# Out:
# <AxesSubplot:title={'center':'Mean Sales in Each Region by Genre'}, ylabel='year_reviewed'>

# %%
total_sales_genre=df.groupby('ingredients').sum().loc[:,sale_columns]
mean_sales_genre=df.groupby('ingredients').mean().loc[:,sale_columns]


fig, axes_genre_heatmap = plt.subplots(1, 2, figsize=(14,8))

axes_genre_heatmap[0].set_title("Total Sales in Each Region by Year")
sns.heatmap(data=total_sales_genre, ax=axes_genre_heatmap[0], annot=True, fmt=".3g")

axes_genre_heatmap[1].set_title("Mean Sales in Each Region by Year")
sns.heatmap(data=mean_sales_genre, ax=axes_genre_heatmap[1], annot=True, fmt=".3g")
plt.show()

# %% [markdown]
# # Conclusion

# %%
data.rating.median()
# Out:
# 3.25

# %%
# select samples with alcohol content rating than the median
low_rating = data[data.rating < 10.2]
# select samples with rating content greater than or equal to the median
high_rating = data[data.rating >= 10.2]
# ensure these queries included each sample exactly once
num_samples = data.shape[0]
num_samples == low_rating['review'].count() + high_rating['review'].count()
# Out:
# True

# %%
# get the median amount of cocoa_percent
data['cocoa_percent'].median()
# Out:
# 70.0

# %%
# get the median amount of num_ingredients
data['num_ingredients'].median()
# Out:
# 3.0

# %%
# get the median amount of year_reviewed
data['year_reviewed'].median()
# Out:
# 2015.0

# %% [markdown]
# # Conclusion

# %% [markdown]
#    As I suspected, this simple EDA is not enough to predict the rating.Future version will include more advanced EDA and NLP to process the more important factors in predicting the rating such as as ingredients and review columns.

# %% [markdown]
# # Conclusion and Recommendation

# %% [markdown]
# ----Sao Tome & Principe ranks high in both cocoa bean origin ratings and manufacturer location ratings,so you should consider adding them to your wishlists
# so you should consider adding them to your wishlists.

# %% [markdown]
# ---The Yearly ratings of chocolate bars have also experienced a steady rise; which indicates the quality is of the bars might have also seen a constant rise.

# %% [markdown]
# ----Further analysis is also required to determine if the number of ingredients used and the percentage of cocoa in the chocolate bars had any effect on the ratings; as preliminary analysis indicated that there was no correlation between the ratings and the aforementioned factors.

# %% [markdown]
# Flavors of Cacao Rating System:
# 5= Elite (Transcending beyond the ordinary limits)
# 4= Premium (Superior flavor development, character and style)
# 3= Satisfactory(3.0) to praiseworthy(3.75) (well made with special qualities)
# 2= Disappointing (Passable but contains at least one significant flaw)
# 1= Unpleasant (mostly unpalatable)

# %% [markdown]
# Each chocolate is evaluated from a combination of both objective qualities and subjective interpretation. A rating here only represents an experience with one bar from one batch. Batch numbers, vintages and review dates are included in the database when known.

# %% [markdown]
# The database is narrowly focused on plain dark chocolate with an aim of appreciating the flavors of the cacao when made into chocolate. The ratings do not reflect health benefits, social missions, or organic status.

# %% [markdown]
# Flavor is the most important component of the Flavors of Cacao ratings. Diversity, balance, intensity and purity of flavors are all considered. It is possible for a straight forward single note chocolate to rate as high as a complex flavor profile that changes throughout. Genetics, terroir, post harvest techniques, processing and storage can all be discussed when considering the flavor component.

# %% [markdown]
# Texture has a great impact on the overall experience and it is also possible for texture related issues to impact flavor. It is a good way to evaluate the makers vision, attention to detail and level of proficiency.

# %% [markdown]
# Overall Opinion is really where the ratings reflect a subjective opinion. Ideally it is my evaluation of whether or not the components above worked together and an opinion on the flavor development, character and style. It is also here where each chocolate can usually be summarized by the most prominent impressions that you would remember about each chocolate.
